# %%
import pandas as pd
import json

# %% [markdown]
# ## Import Data

# %%
# manually specify the data type of specific columns cid_cases
dtype_for_health_quality = {
    'Year': "Int64",
    'Data_Value_Footnote_Symbol': str,
    'Data_Value_Footnote': str,
    'Data_Value_Std_Err': str,
    'Data_Value_Unit': str,
    'Sample_Size': "Int64"
}

df_health_quality = pd.read_csv(
    '../health-related-quality-of-life/rows.csv', 
    dtype=dtype_for_health_quality
)

df_infectious_disease = pd.read_csv(
    '../infectious-disease-2001-2014/rows.csv'
)

# %% [markdown]
# ## Data Cleaning

# %%
# columns to drop
df_health_quality.drop(
    columns=["DataSource",
             "Data_Value_Footnote_Symbol",
             "Data_Value_Footnote",
             "Data_Value_Std_Err",
             "Category",
             "CategoryId",
             "TopicId",
             "QuestionId",
             "LocationId",
             "BreakOutId",
             "BreakOutCategoryid",
             "Data_Value_Unit",
             "GeoLocation"], 
    inplace=True)

# rows to drop
df_health_quality = df_health_quality[df_health_quality['Year'].notna()]

# columns reorder
df_health_quality = df_health_quality[
    ["Year", 
     "LocationAbbr", "LocationDesc",
     'Topic', 'Question',
     'Break_Out_Category', 'Break_Out',
     'Data_Value_Type', 'Data_Value',
     'Low_Confidence_Limit', 'High_Confidence_Limit',
     'Sample_Size',
    ]
]

# %%
df_infectious_disease
# Out:
#             Disease      County  Year     Sex  Count  Population   Rate  \
# 0         Amebiasis  California  2001   Total    571    34514777  1.654
# 1         Amebiasis  California  2001  Female    176    17340743  1.015
# 2         Amebiasis  California  2001    Male    365    17174034  2.125
# 3         Amebiasis  California  2002   Total    442    34940334  1.265
# 4         Amebiasis  California  2002  Female    145    17555714  0.826
# ...             ...         ...   ...     ...    ...         ...    ...
# 141772  Yersiniosis        Yuba  2013  Female      0       36296  0.000
# 141773  Yersiniosis        Yuba  2013    Male      0       36698  0.000
# 141774  Yersiniosis        Yuba  2014   Total      0       73425  0.000
# 141775  Yersiniosis        Yuba  2014  Female      0       36503  0.000
# 141776  Yersiniosis        Yuba  2014    Male      0       36922  0.000
#
#         CI.lower  CI.upper Unstable
# 0          1.521     1.796
# 1          0.871     1.176
# 2          1.913     2.355
# 3          1.150     1.389
# 4          0.697     0.972
# ...          ...       ...      ...
# 141772     0.000    10.163        -
# 141773     0.000    10.051        -
# 141774     0.000     5.024        -
# 141775     0.000    10.105        -
# 141776     0.000     9.991        -
#
# [141777 rows x 10 columns]

# %%
df_health_quality['Break_Out'].unique()
# Out:
# array(['18-24 years old', '25-34 years old', '35-44 years old',
#        '45-54 years old', '55-64 years old', '65-74 years old', '75+',
#        'Female', 'Male', 'Overall', 'Asian/Pacific Islander',
#        'Black non-Hispanic', 'Hispanic', 'Native American/Alaskan Native',
#        'Other non-Hispanic', 'White non-Hispanic'], dtype=object)

# %% [markdown]
# ### Some important attributes

# %%
print(df_health_quality['Topic'].unique())
print(df_health_quality['Data_Value_Type'].unique())
# Out:
# ['Activity Limitation' 'Mental Health' 'General Health' 'Physical Health']
# ['Average number of days' 'Percentage']

# %%
df_test = df_health_quality.loc[
    (df_health_quality['Year']==2010) &
    (df_health_quality['LocationDesc']=='Alabama') &
    (df_health_quality['Topic']=='Physical Health') &
    (df_health_quality['Data_Value_Type'] !='Percentage')
]
df_test
# Out:
#     Year LocationAbbr LocationDesc            Topic  \
# 48  2010           AL      Alabama  Physical Health
# 49  2010           AL      Alabama  Physical Health
# 50  2010           AL      Alabama  Physical Health
# 51  2010           AL      Alabama  Physical Health
# 52  2010           AL      Alabama  Physical Health
# 53  2010           AL      Alabama  Physical Health
# 54  2010           AL      Alabama  Physical Health
# 55  2010           AL      Alabama  Physical Health
# 56  2010           AL      Alabama  Physical Health
# 57  2010           AL      Alabama  Physical Health
# 58  2010           AL      Alabama  Physical Health
# 59  2010           AL      Alabama  Physical Health
# 60  2010           AL      Alabama  Physical Health
# 61  2010           AL      Alabama  Physical Health
# 62  2010           AL      Alabama  Physical Health
# 63  2010           AL      Alabama  Physical Health
#
#                           Question Break_Out_Category  \
# 48  Mean physically unhealthy days          Age Group
# 49  Mean physically unhealthy days          Age Group
# 50  Mean physically unhealthy days          Age Group
# 51  Mean physically unhealthy days          Age Group
# 52  Mean physically unhealthy days          Age Group
# 53  Mean physically unhealthy days          Age Group
# 54  Mean physically unhealthy days          Age Group
# 55  Mean physically unhealthy days             Gender
# 56  Mean physically unhealthy days             Gender
# 57  Mean physically unhealthy days            Overall
# 58  Mean physically unhealthy days     Race/Ethnicity
# 59  Mean physically unhealthy days     Race/Ethnicity
# 60  Mean physically unhealthy days     Race/Ethnicity
# 61  Mean physically unhealthy days     Race/Ethnicity
# 62  Mean physically unhealthy days     Race/Ethnicity
# 63  Mean physically unhealthy days     Race/Ethnicity
#
#                          Break_Out         Data_Value_Type  Data_Value  \
# 48                 18-24 years old  Average number of days         1.9
# 49                 25-34 years old  Average number of days         2.8
# 50                 35-44 years old  Average number of days         3.3
# 51                 45-54 years old  Average number of days         5.4
# 52                 55-64 years old  Average number of days         6.2
# 53                 65-74 years old  Average number of days         5.8
# 54                             75+  Average number of days         6.6
# 55                          Female  Average number of days         5.3
# 56                            Male  Average number of days         3.9
# 57                         Overall  Average number of days         4.6
# 58          Asian/Pacific Islander  Average number of days         NaN
# 59              Black non-Hispanic  Average number of days         4.3
# 60                        Hispanic  Average number of days         3.9
# 61  Native American/Alaskan Native  Average number of days         7.2
# 62              Other non-Hispanic  Average number of days         6.1
# 63              White non-Hispanic  Average number of days         4.7
#
#     Low_Confidence_Limit  High_Confidence_Limit  Sample_Size
# 48                   0.9                    2.8          202
# 49                   2.0                    3.6          597
# 50                   2.5                    4.0          892
# 51                   4.6                    6.1         1352
# 52                   5.4                    6.9         1621
# 53                   5.1                    6.5         1477
# 54                   5.7                    7.5         1008
# 55                   4.8                    5.7         4868
# 56                   3.4                    4.4         2281
# 57                   4.3                    5.0         7149
# 58                   NaN                    NaN         <NA>
# 59                   3.7                    5.0         1764
# 60                   1.7                    6.1           96
# 61                   3.1                   11.3           70
# 62                   2.0                   10.2           39
# 63                   4.3                    5.1         5156

# %% [markdown]
# ## Group By

# %%
# quality of life

# group by
df_health_quality_groupby_YearQuestionBOCatBreakout = df_health_quality.groupby(by=["Year", "Question", "Break_Out_Category", "Break_Out" ], dropna=False).mean()

# make index into columns
df_health_quality_groupby_YearQuestionBOCatBreakout = df_health_quality_groupby_YearQuestionBOCatBreakout.reset_index(level=3).reset_index(level=2).reset_index(level=1).reset_index(level=0)

# display
df_health_quality_groupby_YearQuestionBOCatBreakout
# Out:
#       Year                                        Question Break_Out_Category  \
# 0     1993                Mean days of activity limitation          Age Group
# 1     1993                Mean days of activity limitation          Age Group
# 2     1993                Mean days of activity limitation          Age Group
# 3     1993                Mean days of activity limitation          Age Group
# 4     1993                Mean days of activity limitation          Age Group
# ...    ...                                             ...                ...
# 2299  2010  Percentage with fair or poor self-rated health     Race/Ethnicity
# 2300  2010  Percentage with fair or poor self-rated health     Race/Ethnicity
# 2301  2010  Percentage with fair or poor self-rated health     Race/Ethnicity
# 2302  2010  Percentage with fair or poor self-rated health     Race/Ethnicity
# 2303  2010  Percentage with fair or poor self-rated health     Race/Ethnicity
#
#                            Break_Out  Data_Value  Low_Confidence_Limit  \
# 0                    18-24 years old    1.074510              0.478431
# 1                    25-34 years old    1.154902              0.696078
# 2                    35-44 years old    1.317647              0.770588
# 3                    45-54 years old    1.562745              0.837255
# 4                    55-64 years old    2.025490              1.056863
# ...                              ...         ...                   ...
# 2299              Black non-Hispanic   20.876087             15.226087
# 2300                        Hispanic   18.884615             12.828846
# 2301  Native American/Alaskan Native   27.963636             15.863636
# 2302              Other non-Hispanic   18.345714              8.722857
# 2303              White non-Hispanic   13.794231             12.346154
#
#       High_Confidence_Limit   Sample_Size
# 0                  1.678431    386.588235
# 1                  1.631373    859.294118
# 2                  1.868627    878.235294
# 3                  2.282353    591.098039
# 4                  3.001961    430.039216
# ...                     ...           ...
# 2299              28.606522   1448.695652
# 2300              27.715385   1004.038462
# 2301              44.218182    282.636364
# 2302              34.811429    156.142857
# 2303              15.332692  13007.576923
#
# [2304 rows x 8 columns]

# %%
# group by
df_health_quality_groupby_YearQuestion = df_health_quality.groupby(by=["Year","Question"], dropna=False).mean()

# make index into columns
df_health_quality_groupby_YearQuestion = df_health_quality_groupby_YearQuestion.reset_index(level=1).reset_index(level=0)

# display
df_health_quality_groupby_YearQuestion
# Out:
#      Year                                           Question  Data_Value  \
# 0    1993                   Mean days of activity limitation    1.698054
# 1    1993                       Mean mentally unhealthy days    2.758683
# 2    1993         Mean physically or mentally unhealthy days    5.286677
# 3    1993                     Mean physically unhealthy days    3.186976
# 4    1993  Percentage with 14 or more activity limitation...    5.127695
# ..    ...                                                ...         ...
# 139  2010                     Mean physically unhealthy days    3.757541
# 140  2010  Percentage with 14 or more activity limitation...    7.596958
# 141  2010  Percentage with 14 or more mentally unhealthy ...   10.723194
# 142  2010  Percentage with 14 or more physically unhealth...   11.460330
# 143  2010     Percentage with fair or poor self-rated health   16.854626
#
#      Low_Confidence_Limit  High_Confidence_Limit  Sample_Size
# 0                0.944311               2.468263  1178.806886
# 1                1.855539               3.663174  1178.806886
# 2                4.024850               6.544910  1178.806886
# 3                2.183533               4.194910  1178.806886
# 4                2.462575               7.964371  1178.806886
# ..                    ...                    ...          ...
# 139              2.803042               4.717744  4213.652725
# 140              5.051584              12.306844  4213.652725
# 141              7.400127              16.005830  4213.652725
# 142              8.365146              16.324461  4213.652725
# 143             12.969328              22.224461  4213.652725
#
# [144 rows x 6 columns]

# %%
df_infectious_disease_california = df_infectious_disease[df_infectious_disease['County']=='California']
df_infectious_disease_california = df_infectious_disease_california.drop(columns=['County'])
df_infectious_disease_california
# Out:
#             Disease  Year     Sex  Count  Population   Rate  CI.lower  \
# 0         Amebiasis  2001   Total    571    34514777  1.654     1.521
# 1         Amebiasis  2001  Female    176    17340743  1.015     0.871
# 2         Amebiasis  2001    Male    365    17174034  2.125     1.913
# 3         Amebiasis  2002   Total    442    34940334  1.265     1.150
# 4         Amebiasis  2002  Female    145    17555714  0.826     0.697
# ...             ...   ...     ...    ...         ...    ...       ...
# 139350  Yersiniosis  2013  Female     31    19177344  0.162     0.110
# 139351  Yersiniosis  2013    Male     23    18988773  0.121     0.077
# 139352  Yersiniosis  2014   Total     51    38501494  0.132     0.099
# 139353  Yersiniosis  2014  Female     25    19346905  0.129     0.084
# 139354  Yersiniosis  2014    Male     26    19154588  0.136     0.089
#
#         CI.upper Unstable
# 0          1.796
# 1          1.176
# 2          2.355
# 3          1.389
# 4          0.972
# ...          ...      ...
# 139350     0.229
# 139351     0.182
# 139352     0.174
# 139353     0.191
# 139354     0.199
#
# [2403 rows x 9 columns]

# %% [markdown]
# ## Parse Dataframe to JSON
#
# Edit the functions to acquire desirable json nesting format.

# %%
# store file to react

def write_dict_to_file_QualityOfLife(name, dict_data):
    with open("../../react-app/src/data/quality_of_life_"+name+".json", "w") as write_file:
        json.dump(dict_data, write_file, indent=2)
        
def write_dict_to_file_InfectiousDisease(name, dict_data):
    with open("../../react-app/src/data/infectious_disease_"+name+".json", "w") as write_file:
        json.dump(dict_data, write_file, indent=2)

# %%
# parse df to json

def parse_df_to_json_records(data):
    json_data = data.to_json(orient="records")
    return json.loads(json_data)

# search in list of dict

def find(lst, key, value):
    for i, dic in enumerate(lst):
        if dic[key] == value:
            return i
    return -1

# %%
# unflatten original dict

def unflatten_dict_health_quality(data):
    
    dict_data = {}

    for d in data:
        dict_data[str(d['Year'])] = {}
    
    for d in data:
        dict_data[str(d['Year'])][d['Question']] = {}
    
    for d in data:
        dict_data[str(d['Year'])][d['Question']][d['Break_Out']] = {
            'Data_Value': d['Data_Value'],
            'Low_Confidence_Limit': d['Low_Confidence_Limit'],
            'High_Confidence_Limit': d['High_Confidence_Limit'],
            'Sample_Size': d['Sample_Size']
        }

    # print(json.dumps(dict_data, indent=2))
    return dict_data

def unflatten_dict_cid_cases(data):
    
    dict_data = {}

    for d in data:
        dict_data[d['Disease']] = {}
        
    for d in data:
        dict_data[d['Disease']][d['County']] = {}
    
    for d in data:
        dict_data[d['Disease']][d['County']][str(d['Year'])] = {}
    
    for d in data:
        dict_data[d['Disease']][d['County']][str(d['Year'])][d['Sex']] = {
            'Count': d['Count'],
            'Population': d['Population'],
            'Rate': d['Rate'],
            'CI.lower': d['CI.lower'],
            'CI.upper': d['CI.upper'],
            'Unstable': d['Unstable']
        }

    # print(json.dumps(dict_data, indent=2))
    return dict_data

# %%
def parse_health_quality_groupby_YearQuestion(data):
    
    list_data = []
    
    for d in data:
        
        year_index = find(list_data, 'Year', d['Year'])
        
#         if (year_index == -1):
            list_data.append({
                'Year': d['Year'],
                 d['Question'].replace(" ", "_"): {
                    'Data_Value': d['Data_Value'],
                    'Low_Confidence_Limit': d['Low_Confidence_Limit'],
                    'High_Confidence_Limit': d['High_Confidence_Limit'],
                    'Sample_Size': d['Sample_Size']
                }
            })
        else:
            list_data[year_index][d['Question'].replace(" ", "_")] = {
                'Data_Value': d['Data_Value'],
                'Low_Confidence_Limit': d['Low_Confidence_Limit'],
                'High_Confidence_Limit': d['High_Confidence_Limit'],
                'Sample_Size': d['Sample_Size']
            }
            

    print(list_data)
#     print(json.dumps(dict_data, indent=2))
    return list_data

def parse_health_quality_groupby_YearQuestionBOCatBreakout(data):
    
    dict_data = {}
    
    for d in data:
        dict_data[str(d['Year'])] = {}
    
    for d in data:
        dict_data[str(d['Year'])][d['Question'].replace(" ", "_")] = {}
        
    for d in data:
        dict_data[str(d['Year'])][d['Question'].replace(" ", "_")][d['Break_Out_Category'].replace(" ", "_")] = []
    
    for d in data:
        
        question = d['Question'].replace(" ", "_")
        bo_cat = d['Break_Out_Category'].replace(" ", "_")
        
        dict_data[str(d['Year'])][question][bo_cat].append({
            'Break_Out': d['Break_Out'].replace(" ", "_"),
            'Data_Value': d['Data_Value'],
            'Low_Confidence_Limit': d['Low_Confidence_Limit'],
            'High_Confidence_Limit': d['High_Confidence_Limit'],
            'Sample_Size': d['Sample_Size']
        })

#     print(json.dumps(dict_data, indent=2))
    return dict_data

# %%
def parse_cid_cases_california(data):
    
    dict_data = {}

    for d in data:
        dict_data[d['Disease']] = []
    
    for d in data:
        
        sex_index = find(dict_data[d['Disease']], 'Year', d['Year'])
        
        # data not found
        if (sex_index == -1):
            dict_data[d['Disease']].append({
                'Year': d['Year'],
                 d['Sex']:{
                    'Count': d['Count'],
                    'Population': d['Population'],
                    'Rate': d['Rate'],
                    'CI.lower': d['CI.lower'],
                    'CI.upper': d['CI.upper'],
                    'Unstable': d['Unstable']
                 }  
            })
        else:
            dict_data[d['Disease']][sex_index][d['Sex']] = {
                'Count': d['Count'],
                'Population': d['Population'],
                'Rate': d['Rate'],
                'CI.lower': d['CI.lower'],
                'CI.upper': d['CI.upper'],
                'Unstable': d['Unstable']
            }
            
    print(json.dumps(dict_data, indent=2))
    return dict_data

# %%
# Quality of life

# parsed_health_quality = parse_df_to_json_records(
#     df_health_quality_groupby_YearQuestionBOCatBreakout
# )

# dict_health_quality = parse_health_quality_groupby_YearQuestionBOCatBreakout(
#     parsed_health_quality
# )

# write_dict_to_file_QualityOfLife("groupby_YearQuestionBOCatBreakout", dict_health_quality)

# %%
# infectious disease

parsed_infectious_disease = parse_df_to_json_records(df_infectious_disease_california)
dict_infectious_disease = parse_cid_cases_california(parsed_infectious_disease)
write_dict_to_file_InfectiousDisease("California", dict_infectious_disease)
# Out:
# {
#   "Amebiasis": [
#     {
#       "Year": 2001,
#       "Total": {
#         "Count": 571,
#         "Population": 34514777,
#         "Rate": 1.654,
#         "CI.lower": 1.521,
#         "CI.upper": 1.796,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 176,
#         "Population": 17340743,
#         "Rate": 1.015,
#         "CI.lower": 0.871,
#         "CI.upper": 1.176,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 365,
#         "Population": 17174034,
#         "Rate": 2.125,
#         "CI.lower": 1.913,
#         "CI.upper": 2.355,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2002,
#       "Total": {
#         "Count": 442,
#         "Population": 34940334,
#         "Rate": 1.265,
#         "CI.lower": 1.15,
#         "CI.upper": 1.389,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 145,
#         "Population": 17555714,
#         "Rate": 0.826,
#         "CI.lower": 0.697,
#         "CI.upper": 0.972,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 279,
#         "Population": 17384620,
#         "Rate": 1.605,
#         "CI.lower": 1.422,
#         "CI.upper": 1.805,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2003,
#       "Total": {
#         "Count": 403,
#         "Population": 35390986,
#         "Rate": 1.139,
#         "CI.lower": 1.03,
#         "CI.upper": 1.255,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 127,
#         "Population": 17783924,
#         "Rate": 0.714,
#         "CI.lower": 0.595,
#         "CI.upper": 0.85,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 261,
#         "Population": 17607062,
#         "Rate": 1.482,
#         "CI.lower": 1.308,
#         "CI.upper": 1.674,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2004,
#       "Total": {
#         "Count": 359,
#         "Population": 35754827,
#         "Rate": 1.004,
#         "CI.lower": 0.903,
#         "CI.upper": 1.113,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 101,
#         "Population": 17969405,
#         "Rate": 0.562,
#         "CI.lower": 0.458,
#         "CI.upper": 0.683,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 247,
#         "Population": 17785422,
#         "Rate": 1.389,
#         "CI.lower": 1.221,
#         "CI.upper": 1.573,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2005,
#       "Total": {
#         "Count": 365,
#         "Population": 35987637,
#         "Rate": 1.014,
#         "CI.lower": 0.913,
#         "CI.upper": 1.124,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 103,
#         "Population": 18088355,
#         "Rate": 0.569,
#         "CI.lower": 0.465,
#         "CI.upper": 0.691,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 255,
#         "Population": 17899282,
#         "Rate": 1.425,
#         "CI.lower": 1.255,
#         "CI.upper": 1.611,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2006,
#       "Total": {
#         "Count": 377,
#         "Population": 36248870,
#         "Rate": 1.04,
#         "CI.lower": 0.938,
#         "CI.upper": 1.151,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 110,
#         "Population": 18220429,
#         "Rate": 0.604,
#         "CI.lower": 0.496,
#         "CI.upper": 0.728,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 257,
#         "Population": 18028441,
#         "Rate": 1.426,
#         "CI.lower": 1.257,
#         "CI.upper": 1.611,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2007,
#       "Total": {
#         "Count": 433,
#         "Population": 36554575,
#         "Rate": 1.185,
#         "CI.lower": 1.076,
#         "CI.upper": 1.302,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 142,
#         "Population": 18373955,
#         "Rate": 0.773,
#         "CI.lower": 0.651,
#         "CI.upper": 0.911,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 286,
#         "Population": 18180620,
#         "Rate": 1.573,
#         "CI.lower": 1.396,
#         "CI.upper": 1.766,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2008,
#       "Total": {
#         "Count": 436,
#         "Population": 36858270,
#         "Rate": 1.183,
#         "CI.lower": 1.074,
#         "CI.upper": 1.299,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 147,
#         "Population": 18526603,
#         "Rate": 0.793,
#         "CI.lower": 0.67,
#         "CI.upper": 0.933,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 287,
#         "Population": 18331667,
#         "Rate": 1.566,
#         "CI.lower": 1.39,
#         "CI.upper": 1.758,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2009,
#       "Total": {
#         "Count": 398,
#         "Population": 37079253,
#         "Rate": 1.073,
#         "CI.lower": 0.971,
#         "CI.upper": 1.184,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 112,
#         "Population": 18634031,
#         "Rate": 0.601,
#         "CI.lower": 0.495,
#         "CI.upper": 0.723,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 285,
#         "Population": 18445222,
#         "Rate": 1.545,
#         "CI.lower": 1.371,
#         "CI.upper": 1.735,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2010,
#       "Total": {
#         "Count": 406,
#         "Population": 37311439,
#         "Rate": 1.088,
#         "CI.lower": 0.985,
#         "CI.upper": 1.199,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 108,
#         "Population": 18752748,
#         "Rate": 0.576,
#         "CI.lower": 0.472,
#         "CI.upper": 0.695,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 297,
#         "Population": 18558691,
#         "Rate": 1.6,
#         "CI.lower": 1.423,
#         "CI.upper": 1.793,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2011,
#       "Total": {
#         "Count": 365,
#         "Population": 37572186,
#         "Rate": 0.971,
#         "CI.lower": 0.874,
#         "CI.upper": 1.076,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 118,
#         "Population": 18881056,
#         "Rate": 0.625,
#         "CI.lower": 0.517,
#         "CI.upper": 0.748,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 245,
#         "Population": 18691131,
#         "Rate": 1.311,
#         "CI.lower": 1.152,
#         "CI.upper": 1.486,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2012,
#       "Total": {
#         "Count": 371,
#         "Population": 37869573,
#         "Rate": 0.98,
#         "CI.lower": 0.883,
#         "CI.upper": 1.085,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 101,
#         "Population": 19028077,
#         "Rate": 0.531,
#         "CI.lower": 0.432,
#         "CI.upper": 0.645,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 266,
#         "Population": 18841496,
#         "Rate": 1.412,
#         "CI.lower": 1.247,
#         "CI.upper": 1.592,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2013,
#       "Total": {
#         "Count": 286,
#         "Population": 38166117,
#         "Rate": 0.749,
#         "CI.lower": 0.665,
#         "CI.upper": 0.841,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 66,
#         "Population": 19177344,
#         "Rate": 0.344,
#         "CI.lower": 0.266,
#         "CI.upper": 0.438,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 173,
#         "Population": 18988773,
#         "Rate": 0.911,
#         "CI.lower": 0.78,
#         "CI.upper": 1.057,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2014,
#       "Total": {
#         "Count": 288,
#         "Population": 38501494,
#         "Rate": 0.748,
#         "CI.lower": 0.664,
#         "CI.upper": 0.84,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 73,
#         "Population": 19346905,
#         "Rate": 0.377,
#         "CI.lower": 0.296,
#         "CI.upper": 0.474,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 167,
#         "Population": 19154588,
#         "Rate": 0.872,
#         "CI.lower": 0.745,
#         "CI.upper": 1.015,
#         "Unstable": " "
#       }
#     }
#   ],
#   "Anaplasmosis and Ehrlichiosis": [
#     {
#       "Year": 2001,
#       "Total": {
#         "Count": 1,
#         "Population": 34514777,
#         "Rate": 0.003,
#         "CI.lower": 0.0,
#         "CI.upper": 0.016,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 17340743,
#         "Rate": 0.006,
#         "CI.lower": 0.0,
#         "CI.upper": 0.032,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17174034,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2002,
#       "Total": {
#         "Count": 0,
#         "Population": 34940334,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.011,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17555714,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17384620,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2003,
#       "Total": {
#         "Count": 0,
#         "Population": 35390986,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17783924,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17607062,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2004,
#       "Total": {
#         "Count": 2,
#         "Population": 35754827,
#         "Rate": 0.006,
#         "CI.lower": 0.001,
#         "CI.upper": 0.02,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 17969405,
#         "Rate": 0.006,
#         "CI.lower": 0.0,
#         "CI.upper": 0.031,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 17785422,
#         "Rate": 0.006,
#         "CI.lower": 0.0,
#         "CI.upper": 0.031,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2005,
#       "Total": {
#         "Count": 4,
#         "Population": 35987637,
#         "Rate": 0.011,
#         "CI.lower": 0.003,
#         "CI.upper": 0.028,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 3,
#         "Population": 18088355,
#         "Rate": 0.017,
#         "CI.lower": 0.003,
#         "CI.upper": 0.048,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 17899282,
#         "Rate": 0.006,
#         "CI.lower": 0.0,
#         "CI.upper": 0.031,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2006,
#       "Total": {
#         "Count": 2,
#         "Population": 36248870,
#         "Rate": 0.006,
#         "CI.lower": 0.001,
#         "CI.upper": 0.02,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18220429,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 2,
#         "Population": 18028441,
#         "Rate": 0.011,
#         "CI.lower": 0.001,
#         "CI.upper": 0.04,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2007,
#       "Total": {
#         "Count": 1,
#         "Population": 36554575,
#         "Rate": 0.003,
#         "CI.lower": 0.0,
#         "CI.upper": 0.015,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 18373955,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18180620,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2008,
#       "Total": {
#         "Count": 0,
#         "Population": 36858270,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18526603,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18331667,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2009,
#       "Total": {
#         "Count": 3,
#         "Population": 37079253,
#         "Rate": 0.008,
#         "CI.lower": 0.002,
#         "CI.upper": 0.024,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 2,
#         "Population": 18634031,
#         "Rate": 0.011,
#         "CI.lower": 0.001,
#         "CI.upper": 0.039,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18445222,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2010,
#       "Total": {
#         "Count": 4,
#         "Population": 37311439,
#         "Rate": 0.011,
#         "CI.lower": 0.003,
#         "CI.upper": 0.027,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 3,
#         "Population": 18752748,
#         "Rate": 0.016,
#         "CI.lower": 0.003,
#         "CI.upper": 0.047,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18558691,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2011,
#       "Total": {
#         "Count": 2,
#         "Population": 37572186,
#         "Rate": 0.005,
#         "CI.lower": 0.001,
#         "CI.upper": 0.019,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 18881056,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 18691131,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2012,
#       "Total": {
#         "Count": 7,
#         "Population": 37869573,
#         "Rate": 0.018,
#         "CI.lower": 0.007,
#         "CI.upper": 0.038,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 3,
#         "Population": 19028077,
#         "Rate": 0.016,
#         "CI.lower": 0.003,
#         "CI.upper": 0.046,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 4,
#         "Population": 18841496,
#         "Rate": 0.021,
#         "CI.lower": 0.006,
#         "CI.upper": 0.054,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2013,
#       "Total": {
#         "Count": 11,
#         "Population": 38166117,
#         "Rate": 0.029,
#         "CI.lower": 0.014,
#         "CI.upper": 0.052,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 4,
#         "Population": 19177344,
#         "Rate": 0.021,
#         "CI.lower": 0.006,
#         "CI.upper": 0.053,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 7,
#         "Population": 18988773,
#         "Rate": 0.037,
#         "CI.lower": 0.015,
#         "CI.upper": 0.076,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2014,
#       "Total": {
#         "Count": 7,
#         "Population": 38501494,
#         "Rate": 0.018,
#         "CI.lower": 0.007,
#         "CI.upper": 0.037,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 4,
#         "Population": 19346905,
#         "Rate": 0.021,
#         "CI.lower": 0.006,
#         "CI.upper": 0.053,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 3,
#         "Population": 19154588,
#         "Rate": 0.016,
#         "CI.lower": 0.003,
#         "CI.upper": 0.046,
#         "Unstable": "*"
#       }
#     }
#   ],
#   "Babesiosis": [
#     {
#       "Year": 2001,
#       "Total": {
#         "Count": 0,
#         "Population": 34514777,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.011,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17340743,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17174034,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2002,
#       "Total": {
#         "Count": 0,
#         "Population": 34940334,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.011,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17555714,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17384620,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2003,
#       "Total": {
#         "Count": 0,
#         "Population": 35390986,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17783924,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17607062,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2004,
#       "Total": {
#         "Count": 0,
#         "Population": 35754827,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17969405,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17785422,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2005,
#       "Total": {
#         "Count": 3,
#         "Population": 35987637,
#         "Rate": 0.008,
#         "CI.lower": 0.002,
#         "CI.upper": 0.024,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 18088355,
#         "Rate": 0.006,
#         "CI.lower": 0.0,
#         "CI.upper": 0.031,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 2,
#         "Population": 17899282,
#         "Rate": 0.011,
#         "CI.lower": 0.001,
#         "CI.upper": 0.04,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2006,
#       "Total": {
#         "Count": 1,
#         "Population": 36248870,
#         "Rate": 0.003,
#         "CI.lower": 0.0,
#         "CI.upper": 0.015,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18220429,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 18028441,
#         "Rate": 0.006,
#         "CI.lower": 0.0,
#         "CI.upper": 0.031,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2007,
#       "Total": {
#         "Count": 6,
#         "Population": 36554575,
#         "Rate": 0.016,
#         "CI.lower": 0.006,
#         "CI.upper": 0.036,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 18373955,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 5,
#         "Population": 18180620,
#         "Rate": 0.028,
#         "CI.lower": 0.009,
#         "CI.upper": 0.064,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2008,
#       "Total": {
#         "Count": 1,
#         "Population": 36858270,
#         "Rate": 0.003,
#         "CI.lower": 0.0,
#         "CI.upper": 0.015,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18526603,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 18331667,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2009,
#       "Total": {
#         "Count": 2,
#         "Population": 37079253,
#         "Rate": 0.005,
#         "CI.lower": 0.001,
#         "CI.upper": 0.019,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 18634031,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 18445222,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2010,
#       "Total": {
#         "Count": 3,
#         "Population": 37311439,
#         "Rate": 0.008,
#         "CI.lower": 0.002,
#         "CI.upper": 0.023,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 3,
#         "Population": 18752748,
#         "Rate": 0.016,
#         "CI.lower": 0.003,
#         "CI.upper": 0.047,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18558691,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2011,
#       "Total": {
#         "Count": 2,
#         "Population": 37572186,
#         "Rate": 0.005,
#         "CI.lower": 0.001,
#         "CI.upper": 0.019,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 18881056,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 18691131,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2012,
#       "Total": {
#         "Count": 4,
#         "Population": 37869573,
#         "Rate": 0.011,
#         "CI.lower": 0.003,
#         "CI.upper": 0.027,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 19028077,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.029,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 3,
#         "Population": 18841496,
#         "Rate": 0.016,
#         "CI.lower": 0.003,
#         "CI.upper": 0.047,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2013,
#       "Total": {
#         "Count": 3,
#         "Population": 38166117,
#         "Rate": 0.008,
#         "CI.lower": 0.002,
#         "CI.upper": 0.023,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 19177344,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.019,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 3,
#         "Population": 18988773,
#         "Rate": 0.016,
#         "CI.lower": 0.003,
#         "CI.upper": 0.046,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2014,
#       "Total": {
#         "Count": 3,
#         "Population": 38501494,
#         "Rate": 0.008,
#         "CI.lower": 0.002,
#         "CI.upper": 0.023,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 2,
#         "Population": 19346905,
#         "Rate": 0.01,
#         "CI.lower": 0.001,
#         "CI.upper": 0.037,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 19154588,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.029,
#         "Unstable": "*"
#       }
#     }
#   ],
#   "Botulism, Foodborne": [
#     {
#       "Year": 2001,
#       "Total": {
#         "Count": 4,
#         "Population": 34514777,
#         "Rate": 0.012,
#         "CI.lower": 0.003,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 2,
#         "Population": 17340743,
#         "Rate": 0.012,
#         "CI.lower": 0.001,
#         "CI.upper": 0.042,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 2,
#         "Population": 17174034,
#         "Rate": 0.012,
#         "CI.lower": 0.001,
#         "CI.upper": 0.042,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2002,
#       "Total": {
#         "Count": 0,
#         "Population": 34940334,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.011,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17555714,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17384620,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2003,
#       "Total": {
#         "Count": 2,
#         "Population": 35390986,
#         "Rate": 0.006,
#         "CI.lower": 0.001,
#         "CI.upper": 0.02,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 2,
#         "Population": 17783924,
#         "Rate": 0.011,
#         "CI.lower": 0.001,
#         "CI.upper": 0.041,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17607062,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2004,
#       "Total": {
#         "Count": 5,
#         "Population": 35754827,
#         "Rate": 0.014,
#         "CI.lower": 0.005,
#         "CI.upper": 0.033,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17969405,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 5,
#         "Population": 17785422,
#         "Rate": 0.028,
#         "CI.lower": 0.009,
#         "CI.upper": 0.066,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2005,
#       "Total": {
#         "Count": 3,
#         "Population": 35987637,
#         "Rate": 0.008,
#         "CI.lower": 0.002,
#         "CI.upper": 0.024,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18088355,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 3,
#         "Population": 17899282,
#         "Rate": 0.017,
#         "CI.lower": 0.003,
#         "CI.upper": 0.049,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2006,
#       "Total": {
#         "Count": 6,
#         "Population": 36248870,
#         "Rate": 0.017,
#         "CI.lower": 0.006,
#         "CI.upper": 0.036,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 3,
#         "Population": 18220429,
#         "Rate": 0.016,
#         "CI.lower": 0.003,
#         "CI.upper": 0.048,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 3,
#         "Population": 18028441,
#         "Rate": 0.017,
#         "CI.lower": 0.003,
#         "CI.upper": 0.049,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2007,
#       "Total": {
#         "Count": 2,
#         "Population": 36554575,
#         "Rate": 0.005,
#         "CI.lower": 0.001,
#         "CI.upper": 0.02,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 18373955,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 18180620,
#         "Rate": 0.006,
#         "CI.lower": 0.0,
#         "CI.upper": 0.031,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2008,
#       "Total": {
#         "Count": 3,
#         "Population": 36858270,
#         "Rate": 0.008,
#         "CI.lower": 0.002,
#         "CI.upper": 0.024,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 18526603,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 2,
#         "Population": 18331667,
#         "Rate": 0.011,
#         "CI.lower": 0.001,
#         "CI.upper": 0.039,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2009,
#       "Total": {
#         "Count": 3,
#         "Population": 37079253,
#         "Rate": 0.008,
#         "CI.lower": 0.002,
#         "CI.upper": 0.024,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 18634031,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 2,
#         "Population": 18445222,
#         "Rate": 0.011,
#         "CI.lower": 0.001,
#         "CI.upper": 0.039,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2010,
#       "Total": {
#         "Count": 1,
#         "Population": 37311439,
#         "Rate": 0.003,
#         "CI.lower": 0.0,
#         "CI.upper": 0.015,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18752748,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 18558691,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2011,
#       "Total": {
#         "Count": 1,
#         "Population": 37572186,
#         "Rate": 0.003,
#         "CI.lower": 0.0,
#         "CI.upper": 0.015,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18881056,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 18691131,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2012,
#       "Total": {
#         "Count": 1,
#         "Population": 37869573,
#         "Rate": 0.003,
#         "CI.lower": 0.0,
#         "CI.upper": 0.015,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 19028077,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.029,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18841496,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2013,
#       "Total": {
#         "Count": 1,
#         "Population": 38166117,
#         "Rate": 0.003,
#         "CI.lower": 0.0,
#         "CI.upper": 0.015,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 19177344,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.029,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18988773,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.019,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2014,
#       "Total": {
#         "Count": 0,
#         "Population": 38501494,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 19346905,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.019,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 19154588,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.019,
#         "Unstable": "-"
#       }
#     }
#   ],
#   "Botulism, Other": [
#     {
#       "Year": 2001,
#       "Total": {
#         "Count": 0,
#         "Population": 34514777,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.011,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17340743,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17174034,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2002,
#       "Total": {
#         "Count": 0,
#         "Population": 34940334,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.011,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17555714,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17384620,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2003,
#       "Total": {
#         "Count": 0,
#         "Population": 35390986,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17783924,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17607062,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2004,
#       "Total": {
#         "Count": 0,
#         "Population": 35754827,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 17969405,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17785422,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2005,
#       "Total": {
#         "Count": 0,
#         "Population": 35987637,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18088355,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 17899282,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.021,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2006,
#       "Total": {
#         "Count": 0,
#         "Population": 36248870,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18220429,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18028441,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2007,
#       "Total": {
#         "Count": 0,
#         "Population": 36554575,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18373955,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18180620,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2008,
#       "Total": {
#         "Count": 0,
#         "Population": 36858270,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18526603,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18331667,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2009,
#       "Total": {
#         "Count": 0,
#         "Population": 37079253,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18634031,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18445222,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2010,
#       "Total": {
#         "Count": 0,
#         "Population": 37311439,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 18752748,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18558691,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.02,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2011,
#       "Total": {
#         "Count": 3,
#         "Population": 37572186,
#         "Rate": 0.008,
#         "CI.lower": 0.002,
#         "CI.upper": 0.023,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 2,
#         "Population": 18881056,
#         "Rate": 0.011,
#         "CI.lower": 0.001,
#         "CI.upper": 0.038,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 18691131,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2012,
#       "Total": {
#         "Count": 2,
#         "Population": 37869573,
#         "Rate": 0.005,
#         "CI.lower": 0.001,
#         "CI.upper": 0.019,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 19028077,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.019,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 2,
#         "Population": 18841496,
#         "Rate": 0.011,
#         "CI.lower": 0.001,
#         "CI.upper": 0.038,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2013,
#       "Total": {
#         "Count": 0,
#         "Population": 38166117,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.01,
#         "Unstable": "-"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 19177344,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.019,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 0,
#         "Population": 18988773,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.019,
#         "Unstable": "-"
#       }
#     },
#     {
#       "Year": 2014,
#       "Total": {
#         "Count": 1,
#         "Population": 38501494,
#         "Rate": 0.003,
#         "CI.lower": 0.0,
#         "CI.upper": 0.014,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 19346905,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.019,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 1,
#         "Population": 19154588,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.029,
#         "Unstable": "*"
#       }
#     }
#   ],
#   "Botulism, Wound": [
#     {
#       "Year": 2001,
#       "Total": {
#         "Count": 20,
#         "Population": 34514777,
#         "Rate": 0.058,
#         "CI.lower": 0.035,
#         "CI.upper": 0.089,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 9,
#         "Population": 17340743,
#         "Rate": 0.052,
#         "CI.lower": 0.024,
#         "CI.upper": 0.099,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 11,
#         "Population": 17174034,
#         "Rate": 0.064,
#         "CI.lower": 0.032,
#         "CI.upper": 0.115,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2002,
#       "Total": {
#         "Count": 23,
#         "Population": 34940334,
#         "Rate": 0.066,
#         "CI.lower": 0.042,
#         "CI.upper": 0.099,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 4,
#         "Population": 17555714,
#         "Rate": 0.023,
#         "CI.lower": 0.006,
#         "CI.upper": 0.058,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 19,
#         "Population": 17384620,
#         "Rate": 0.109,
#         "CI.lower": 0.066,
#         "CI.upper": 0.171,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2003,
#       "Total": {
#         "Count": 21,
#         "Population": 35390986,
#         "Rate": 0.059,
#         "CI.lower": 0.037,
#         "CI.upper": 0.091,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 5,
#         "Population": 17783924,
#         "Rate": 0.028,
#         "CI.lower": 0.009,
#         "CI.upper": 0.066,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 16,
#         "Population": 17607062,
#         "Rate": 0.091,
#         "CI.lower": 0.052,
#         "CI.upper": 0.148,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2004,
#       "Total": {
#         "Count": 18,
#         "Population": 35754827,
#         "Rate": 0.05,
#         "CI.lower": 0.03,
#         "CI.upper": 0.08,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 2,
#         "Population": 17969405,
#         "Rate": 0.011,
#         "CI.lower": 0.001,
#         "CI.upper": 0.04,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 16,
#         "Population": 17785422,
#         "Rate": 0.09,
#         "CI.lower": 0.051,
#         "CI.upper": 0.146,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2005,
#       "Total": {
#         "Count": 27,
#         "Population": 35987637,
#         "Rate": 0.075,
#         "CI.lower": 0.049,
#         "CI.upper": 0.109,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 4,
#         "Population": 18088355,
#         "Rate": 0.022,
#         "CI.lower": 0.006,
#         "CI.upper": 0.057,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 23,
#         "Population": 17899282,
#         "Rate": 0.128,
#         "CI.lower": 0.081,
#         "CI.upper": 0.193,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2006,
#       "Total": {
#         "Count": 38,
#         "Population": 36248870,
#         "Rate": 0.105,
#         "CI.lower": 0.074,
#         "CI.upper": 0.144,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 11,
#         "Population": 18220429,
#         "Rate": 0.06,
#         "CI.lower": 0.03,
#         "CI.upper": 0.108,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 27,
#         "Population": 18028441,
#         "Rate": 0.15,
#         "CI.lower": 0.099,
#         "CI.upper": 0.218,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2007,
#       "Total": {
#         "Count": 19,
#         "Population": 36554575,
#         "Rate": 0.052,
#         "CI.lower": 0.031,
#         "CI.upper": 0.081,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 4,
#         "Population": 18373955,
#         "Rate": 0.022,
#         "CI.lower": 0.006,
#         "CI.upper": 0.056,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 15,
#         "Population": 18180620,
#         "Rate": 0.083,
#         "CI.lower": 0.046,
#         "CI.upper": 0.136,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2008,
#       "Total": {
#         "Count": 18,
#         "Population": 36858270,
#         "Rate": 0.049,
#         "CI.lower": 0.029,
#         "CI.upper": 0.077,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 6,
#         "Population": 18526603,
#         "Rate": 0.032,
#         "CI.lower": 0.012,
#         "CI.upper": 0.07,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 12,
#         "Population": 18331667,
#         "Rate": 0.065,
#         "CI.lower": 0.034,
#         "CI.upper": 0.114,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2009,
#       "Total": {
#         "Count": 18,
#         "Population": 37079253,
#         "Rate": 0.049,
#         "CI.lower": 0.029,
#         "CI.upper": 0.077,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 6,
#         "Population": 18634031,
#         "Rate": 0.032,
#         "CI.lower": 0.012,
#         "CI.upper": 0.07,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 12,
#         "Population": 18445222,
#         "Rate": 0.065,
#         "CI.lower": 0.034,
#         "CI.upper": 0.114,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2010,
#       "Total": {
#         "Count": 16,
#         "Population": 37311439,
#         "Rate": 0.043,
#         "CI.lower": 0.025,
#         "CI.upper": 0.07,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 18752748,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.03,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 15,
#         "Population": 18558691,
#         "Rate": 0.081,
#         "CI.lower": 0.045,
#         "CI.upper": 0.133,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2011,
#       "Total": {
#         "Count": 9,
#         "Population": 37572186,
#         "Rate": 0.024,
#         "CI.lower": 0.011,
#         "CI.upper": 0.045,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 2,
#         "Population": 18881056,
#         "Rate": 0.011,
#         "CI.lower": 0.001,
#         "CI.upper": 0.038,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 6,
#         "Population": 18691131,
#         "Rate": 0.032,
#         "CI.lower": 0.012,
#         "CI.upper": 0.07,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2012,
#       "Total": {
#         "Count": 7,
#         "Population": 37869573,
#         "Rate": 0.018,
#         "CI.lower": 0.007,
#         "CI.upper": 0.038,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 1,
#         "Population": 19028077,
#         "Rate": 0.005,
#         "CI.lower": 0.0,
#         "CI.upper": 0.029,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 6,
#         "Population": 18841496,
#         "Rate": 0.032,
#         "CI.lower": 0.012,
#         "CI.upper": 0.069,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2013,
#       "Total": {
#         "Count": 9,
#         "Population": 38166117,
#         "Rate": 0.024,
#         "CI.lower": 0.011,
#         "CI.upper": 0.045,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 0,
#         "Population": 19177344,
#         "Rate": 0.0,
#         "CI.lower": 0.0,
#         "CI.upper": 0.019,
#         "Unstable": "-"
#       },
#       "Male": {
#         "Count": 9,
#         "Population": 18988773,
#         "Rate": 0.047,
#         "CI.lower": 0.022,
#         "CI.upper": 0.09,
#         "Unstable": "*"
#       }
#     },
#     {
#       "Year": 2014,
#       "Total": {
#         "Count": 13,
#         "Population": 38501494,
#         "Rate": 0.034,
#         "CI.lower": 0.018,
#         "CI.upper": 0.058,
#         "Unstable": "*"
#       },
#       "Female": {
#         "Count": 3,
#         "Population": 19346905,
#         "Rate": 0.016,
#         "CI.lower": 0.003,
#         "CI.upper": 0.045,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 10,
#         "Population": 19154588,
#         "Rate": 0.052,
#         "CI.lower": 0.025,
#         "CI.upper": 0.096,
#         "Unstable": "*"
#       }
#     }
#   ],
#   "Brucellosis": [
#     {
#       "Year": 2001,
#       "Total": {
#         "Count": 36,
#         "Population": 34514777,
#         "Rate": 0.104,
#         "CI.lower": 0.073,
#         "CI.upper": 0.144,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 20,
#         "Population": 17340743,
#         "Rate": 0.115,
#         "CI.lower": 0.07,
#         "CI.upper": 0.178,
#         "Unstable": " "
#       },
# ...
#       "Total": {
#         "Count": 76,
#         "Population": 34514777,
#         "Rate": 0.22,
#         "CI.lower": 0.173,
#         "CI.upper": 0.276,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 21,
#         "Population": 17340743,
#         "Rate": 0.121,
#         "CI.lower": 0.075,
#         "CI.upper": 0.185,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 54,
#         "Population": 17174034,
#         "Rate": 0.314,
#         "CI.lower": 0.236,
#         "CI.upper": 0.41,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2002,
#       "Total": {
#         "Count": 52,
#         "Population": 34940334,
#         "Rate": 0.149,
#         "CI.lower": 0.111,
#         "CI.upper": 0.195,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 13,
#         "Population": 17555714,
#         "Rate": 0.074,
#         "CI.lower": 0.039,
#         "CI.upper": 0.127,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 38,
#         "Population": 17384620,
#         "Rate": 0.219,
#         "CI.lower": 0.155,
#         "CI.upper": 0.3,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2003,
#       "Total": {
#         "Count": 74,
#         "Population": 35390986,
#         "Rate": 0.209,
#         "CI.lower": 0.164,
#         "CI.upper": 0.262,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 16,
#         "Population": 17783924,
#         "Rate": 0.09,
#         "CI.lower": 0.051,
#         "CI.upper": 0.146,
#         "Unstable": "*"
#       },
#       "Male": {
#         "Count": 58,
#         "Population": 17607062,
#         "Rate": 0.329,
#         "CI.lower": 0.25,
#         "CI.upper": 0.426,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2004,
#       "Total": {
#         "Count": 146,
#         "Population": 35754827,
#         "Rate": 0.408,
#         "CI.lower": 0.345,
#         "CI.upper": 0.48,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 41,
#         "Population": 17969405,
#         "Rate": 0.228,
#         "CI.lower": 0.164,
#         "CI.upper": 0.31,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 104,
#         "Population": 17785422,
#         "Rate": 0.585,
#         "CI.lower": 0.478,
#         "CI.upper": 0.709,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2005,
#       "Total": {
#         "Count": 99,
#         "Population": 35987637,
#         "Rate": 0.275,
#         "CI.lower": 0.224,
#         "CI.upper": 0.335,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 35,
#         "Population": 18088355,
#         "Rate": 0.193,
#         "CI.lower": 0.135,
#         "CI.upper": 0.269,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 64,
#         "Population": 17899282,
#         "Rate": 0.358,
#         "CI.lower": 0.275,
#         "CI.upper": 0.457,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2006,
#       "Total": {
#         "Count": 176,
#         "Population": 36248870,
#         "Rate": 0.486,
#         "CI.lower": 0.416,
#         "CI.upper": 0.563,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 65,
#         "Population": 18220429,
#         "Rate": 0.357,
#         "CI.lower": 0.275,
#         "CI.upper": 0.455,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 110,
#         "Population": 18028441,
#         "Rate": 0.61,
#         "CI.lower": 0.501,
#         "CI.upper": 0.735,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2007,
#       "Total": {
#         "Count": 95,
#         "Population": 36554575,
#         "Rate": 0.26,
#         "CI.lower": 0.21,
#         "CI.upper": 0.318,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 28,
#         "Population": 18373955,
#         "Rate": 0.152,
#         "CI.lower": 0.101,
#         "CI.upper": 0.22,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 67,
#         "Population": 18180620,
#         "Rate": 0.369,
#         "CI.lower": 0.286,
#         "CI.upper": 0.468,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2008,
#       "Total": {
#         "Count": 110,
#         "Population": 36858270,
#         "Rate": 0.298,
#         "CI.lower": 0.245,
#         "CI.upper": 0.36,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 28,
#         "Population": 18526603,
#         "Rate": 0.151,
#         "CI.lower": 0.1,
#         "CI.upper": 0.218,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 80,
#         "Population": 18331667,
#         "Rate": 0.436,
#         "CI.lower": 0.346,
#         "CI.upper": 0.543,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2009,
#       "Total": {
#         "Count": 138,
#         "Population": 37079253,
#         "Rate": 0.372,
#         "CI.lower": 0.313,
#         "CI.upper": 0.44,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 50,
#         "Population": 18634031,
#         "Rate": 0.268,
#         "CI.lower": 0.199,
#         "CI.upper": 0.354,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 87,
#         "Population": 18445222,
#         "Rate": 0.472,
#         "CI.lower": 0.378,
#         "CI.upper": 0.582,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2010,
#       "Total": {
#         "Count": 110,
#         "Population": 37311439,
#         "Rate": 0.295,
#         "CI.lower": 0.242,
#         "CI.upper": 0.355,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 41,
#         "Population": 18752748,
#         "Rate": 0.219,
#         "CI.lower": 0.157,
#         "CI.upper": 0.297,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 68,
#         "Population": 18558691,
#         "Rate": 0.366,
#         "CI.lower": 0.285,
#         "CI.upper": 0.465,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2011,
#       "Total": {
#         "Count": 105,
#         "Population": 37572186,
#         "Rate": 0.279,
#         "CI.lower": 0.229,
#         "CI.upper": 0.338,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 40,
#         "Population": 18881056,
#         "Rate": 0.212,
#         "CI.lower": 0.151,
#         "CI.upper": 0.288,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 65,
#         "Population": 18691131,
#         "Rate": 0.348,
#         "CI.lower": 0.268,
#         "CI.upper": 0.443,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2012,
#       "Total": {
#         "Count": 184,
#         "Population": 37869573,
#         "Rate": 0.486,
#         "CI.lower": 0.418,
#         "CI.upper": 0.561,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 62,
#         "Population": 19028077,
#         "Rate": 0.326,
#         "CI.lower": 0.25,
#         "CI.upper": 0.418,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 122,
#         "Population": 18841496,
#         "Rate": 0.648,
#         "CI.lower": 0.538,
#         "CI.upper": 0.773,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2013,
#       "Total": {
#         "Count": 150,
#         "Population": 38166117,
#         "Rate": 0.393,
#         "CI.lower": 0.333,
#         "CI.upper": 0.461,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 48,
#         "Population": 19177344,
#         "Rate": 0.25,
#         "CI.lower": 0.185,
#         "CI.upper": 0.332,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 102,
#         "Population": 18988773,
#         "Rate": 0.537,
#         "CI.lower": 0.438,
#         "CI.upper": 0.652,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2014,
#       "Total": {
#         "Count": 269,
#         "Population": 38501494,
#         "Rate": 0.699,
#         "CI.lower": 0.618,
#         "CI.upper": 0.787,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 87,
#         "Population": 19346905,
#         "Rate": 0.45,
#         "CI.lower": 0.36,
#         "CI.upper": 0.555,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 182,
#         "Population": 19154588,
#         "Rate": 0.95,
#         "CI.lower": 0.817,
#         "CI.upper": 1.099,
#         "Unstable": " "
#       }
#     }
#   ],
#   "Yersiniosis": [
#     {
#       "Year": 2001,
#       "Total": {
#         "Count": 81,
#         "Population": 34514777,
#         "Rate": 0.235,
#         "CI.lower": 0.186,
#         "CI.upper": 0.292,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 32,
#         "Population": 17340743,
#         "Rate": 0.185,
#         "CI.lower": 0.126,
#         "CI.upper": 0.261,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 48,
#         "Population": 17174034,
#         "Rate": 0.279,
#         "CI.lower": 0.206,
#         "CI.upper": 0.371,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2002,
#       "Total": {
#         "Count": 67,
#         "Population": 34940334,
#         "Rate": 0.192,
#         "CI.lower": 0.149,
#         "CI.upper": 0.244,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 24,
#         "Population": 17555714,
#         "Rate": 0.137,
#         "CI.lower": 0.088,
#         "CI.upper": 0.203,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 40,
#         "Population": 17384620,
#         "Rate": 0.23,
#         "CI.lower": 0.164,
#         "CI.upper": 0.313,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2003,
#       "Total": {
#         "Count": 78,
#         "Population": 35390986,
#         "Rate": 0.22,
#         "CI.lower": 0.174,
#         "CI.upper": 0.275,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 31,
#         "Population": 17783924,
#         "Rate": 0.174,
#         "CI.lower": 0.118,
#         "CI.upper": 0.247,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 46,
#         "Population": 17607062,
#         "Rate": 0.261,
#         "CI.lower": 0.191,
#         "CI.upper": 0.348,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2004,
#       "Total": {
#         "Count": 89,
#         "Population": 35754827,
#         "Rate": 0.249,
#         "CI.lower": 0.2,
#         "CI.upper": 0.306,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 39,
#         "Population": 17969405,
#         "Rate": 0.217,
#         "CI.lower": 0.154,
#         "CI.upper": 0.297,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 50,
#         "Population": 17785422,
#         "Rate": 0.281,
#         "CI.lower": 0.209,
#         "CI.upper": 0.371,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2005,
#       "Total": {
#         "Count": 110,
#         "Population": 35987637,
#         "Rate": 0.306,
#         "CI.lower": 0.251,
#         "CI.upper": 0.368,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 52,
#         "Population": 18088355,
#         "Rate": 0.287,
#         "CI.lower": 0.215,
#         "CI.upper": 0.377,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 57,
#         "Population": 17899282,
#         "Rate": 0.318,
#         "CI.lower": 0.241,
#         "CI.upper": 0.413,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2006,
#       "Total": {
#         "Count": 73,
#         "Population": 36248870,
#         "Rate": 0.201,
#         "CI.lower": 0.158,
#         "CI.upper": 0.253,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 37,
#         "Population": 18220429,
#         "Rate": 0.203,
#         "CI.lower": 0.143,
#         "CI.upper": 0.28,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 36,
#         "Population": 18028441,
#         "Rate": 0.2,
#         "CI.lower": 0.14,
#         "CI.upper": 0.276,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2007,
#       "Total": {
#         "Count": 97,
#         "Population": 36554575,
#         "Rate": 0.265,
#         "CI.lower": 0.215,
#         "CI.upper": 0.324,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 43,
#         "Population": 18373955,
#         "Rate": 0.234,
#         "CI.lower": 0.169,
#         "CI.upper": 0.315,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 53,
#         "Population": 18180620,
#         "Rate": 0.292,
#         "CI.lower": 0.218,
#         "CI.upper": 0.381,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2008,
#       "Total": {
#         "Count": 84,
#         "Population": 36858270,
#         "Rate": 0.228,
#         "CI.lower": 0.182,
#         "CI.upper": 0.282,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 37,
#         "Population": 18526603,
#         "Rate": 0.2,
#         "CI.lower": 0.141,
#         "CI.upper": 0.275,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 46,
#         "Population": 18331667,
#         "Rate": 0.251,
#         "CI.lower": 0.184,
#         "CI.upper": 0.335,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2009,
#       "Total": {
#         "Count": 87,
#         "Population": 37079253,
#         "Rate": 0.235,
#         "CI.lower": 0.188,
#         "CI.upper": 0.289,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 41,
#         "Population": 18634031,
#         "Rate": 0.22,
#         "CI.lower": 0.158,
#         "CI.upper": 0.298,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 44,
#         "Population": 18445222,
#         "Rate": 0.239,
#         "CI.lower": 0.173,
#         "CI.upper": 0.32,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2010,
#       "Total": {
#         "Count": 65,
#         "Population": 37311439,
#         "Rate": 0.174,
#         "CI.lower": 0.134,
#         "CI.upper": 0.222,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 29,
#         "Population": 18752748,
#         "Rate": 0.155,
#         "CI.lower": 0.104,
#         "CI.upper": 0.222,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 35,
#         "Population": 18558691,
#         "Rate": 0.189,
#         "CI.lower": 0.131,
#         "CI.upper": 0.262,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2011,
#       "Total": {
#         "Count": 67,
#         "Population": 37572186,
#         "Rate": 0.178,
#         "CI.lower": 0.138,
#         "CI.upper": 0.226,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 34,
#         "Population": 18881056,
#         "Rate": 0.18,
#         "CI.lower": 0.125,
#         "CI.upper": 0.252,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 32,
#         "Population": 18691131,
#         "Rate": 0.171,
#         "CI.lower": 0.117,
#         "CI.upper": 0.242,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2012,
#       "Total": {
#         "Count": 58,
#         "Population": 37869573,
#         "Rate": 0.153,
#         "CI.lower": 0.116,
#         "CI.upper": 0.198,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 24,
#         "Population": 19028077,
#         "Rate": 0.126,
#         "CI.lower": 0.081,
#         "CI.upper": 0.188,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 34,
#         "Population": 18841496,
#         "Rate": 0.18,
#         "CI.lower": 0.125,
#         "CI.upper": 0.252,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2013,
#       "Total": {
#         "Count": 54,
#         "Population": 38166117,
#         "Rate": 0.141,
#         "CI.lower": 0.106,
#         "CI.upper": 0.185,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 31,
#         "Population": 19177344,
#         "Rate": 0.162,
#         "CI.lower": 0.11,
#         "CI.upper": 0.229,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 23,
#         "Population": 18988773,
#         "Rate": 0.121,
#         "CI.lower": 0.077,
#         "CI.upper": 0.182,
#         "Unstable": " "
#       }
#     },
#     {
#       "Year": 2014,
#       "Total": {
#         "Count": 51,
#         "Population": 38501494,
#         "Rate": 0.132,
#         "CI.lower": 0.099,
#         "CI.upper": 0.174,
#         "Unstable": " "
#       },
#       "Female": {
#         "Count": 25,
#         "Population": 19346905,
#         "Rate": 0.129,
#         "CI.lower": 0.084,
#         "CI.upper": 0.191,
#         "Unstable": " "
#       },
#       "Male": {
#         "Count": 26,
#         "Population": 19154588,
#         "Rate": 0.136,
#         "CI.lower": 0.089,
#         "CI.upper": 0.199,
#         "Unstable": " "
#       }
#     }
#   ]
# }
